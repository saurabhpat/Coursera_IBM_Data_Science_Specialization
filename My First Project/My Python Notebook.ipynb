# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Saurabh Patil**
# Technical Consultant

# %% [markdown]
# _I am interested in data science because I am interested in learning consumer purchasing behaviour. I am keen to learning what motivates a consumer to purchase a particular product._

# %% [markdown]
# ## Below is my Python Code for simple addition of two numbers

# %%
1+2
# Out:
# 3

# %% [markdown]
# ~~I shouldn't be writing this~~
# 1. First ordered list
# [This is a link to something](https://brightside.me/wonder-curiosities/19-photos-hiding-something-interesting-hint-you-just-have-to-look-a-little-closer-556360/)
